# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('clean_data_Water_quality.csv')
df =df.iloc[:,1:]

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.469956    32.879761   8768.570828     1.583085    36.142612
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.080795   196.967627  20927.833607     7.130299   333.775777
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        15.769881     0.780382     0.487849
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
classifier = []

classifier.append(('standardize', StandardScaler()))
classifier.append(("model",RandomForestClassifier()))

# %%
X = df.drop('Potability', axis=1)
y = df.Potability

# %%
model = Pipeline(classifier)
model.fit(X,y)
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('model', RandomForestClassifier())])

# %%
dict(df.iloc[2000,:])
# Out:
# {'ph': 7.442023084023342,
#  'Hardness': 194.76387129742383,
#  'Solids': 34565.70169026524,
#  'Chloramines': 8.49334762370914,
#  'Sulfate': 294.83621768880164,
#  'Conductivity': 350.0851155438649,
#  'Organic_carbon': 18.96201400930363,
#  'Trihalomethanes': 79.95832130270405,
#  'Turbidity': 2.894651172139397,
#  'Potability': 1.0}

# %%
dict(df.iloc[200,:])
# Out:
# {'ph': 5.970035656942926,
#  'Hardness': 230.4493293243112,
#  'Solids': 16324.115196182343,
#  'Chloramines': 5.293918606634048,
#  'Sulfate': 315.18612058925714,
#  'Conductivity': 327.7866419581865,
#  'Organic_carbon': 13.325987078606149,
#  'Trihalomethanes': 39.55424883045545,
#  'Turbidity': 5.428674071623728,
#  'Potability': 0.0}

# %%
new = {'ph': 5.970035656942926,
 'Hardness': 230.4493293243112,
 'Solids': 16324.115196182343,
 'Chloramines': 5.293918606634048,
 'Sulfate': 315.18612058925714,
 'Conductivity': 327.7866419581865,
 'Organic_carbon': 13.325987078606149,
 'Trihalomethanes': 39.55424883045545,
 'Turbidity': 5.428674071623728}

# %%
new = {'ph': 7.442023084023342,
 'Hardness': 194.76387129742383,
 'Solids': 34565.70169026524,
 'Chloramines': 8.49334762370914,
 'Sulfate': 294.83621768880164,
 'Conductivity': 350.0851155438649,
 'Organic_carbon': 18.96201400930363,
 'Trihalomethanes': 79.95832130270405,
 'Turbidity': 2.894651172139397}

# %%
new = {'ph': 7.44,
 'Hardness': 194.76,
 'Solids': 34565.70,
 'Chloramines': 8.49,
 'Sulfate': 294.83,
 'Conductivity': 350.089,
 'Organic_carbon': 18.96,
 'Trihalomethanes': 79.95,
 'Turbidity': 2.89}

# %%
data = pd.DataFrame(new,index = [0])

# %%
data
# Out:
#      ph  Hardness   Solids  Chloramines  Sulfate  Conductivity  \
# 0  7.44    194.76  34565.7         8.49   294.83       350.089
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0           18.96            79.95       2.89

# %%
model.predict(data)
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Model Saving

# %%
import pickle

with open("model.sav",mode="wb") as f1:
    pickle.dump(model,f1)
